# %%
import seaborn as sns
import pandas as pd

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# dictionaries
d = {'name':['sumit','aniket','krish'],
     'age':[1,2,3]}

# %%
type(d)
# Out:
# dict

# %%
d['name']
# Out:
# ['sumit', 'aniket', 'krish']

# %%
d['age']
# Out:
# [1, 2, 3]

# %%
tips['day']
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
d
# Out:
# {'name': ['sumit', 'aniket', 'krish'], 'age': [1, 2, 3]}

# %%
pd.DataFrame(d)
# Out:
#      name  age
# 0   sumit    1
# 1  aniket    2
# 2   krish    3

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.rename(columns = {'sex':'gender','total_bill':'total'},inplace = True )

# %%
tips
# Out:
#      total   tip  gender smoker   day    time  size
# 0    16.99  1.01  Female     No   Sun  Dinner     2
# 1    10.34  1.66    Male     No   Sun  Dinner     3
# 2    21.01  3.50    Male     No   Sun  Dinner     3
# 3    23.68  3.31    Male     No   Sun  Dinner     2
# 4    24.59  3.61  Female     No   Sun  Dinner     4
# ..     ...   ...     ...    ...   ...     ...   ...
# 239  29.03  5.92    Male     No   Sat  Dinner     3
# 240  27.18  2.00  Female    Yes   Sat  Dinner     2
# 241  22.67  2.00    Male    Yes   Sat  Dinner     2
# 242  17.82  1.75    Male     No   Sat  Dinner     2
# 243  18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import numpy as np

# %%
x = np.random.randint(1,100,(10,2))

# %%
pd.DataFrame(x,columns = ['A','B'])
# Out:
#     A   B
# 0  77  29
# 1  21  23
# 2  43  71
# 3  26  54
# 4  18  89
# 5  88  73
# 6  55  73
# 7  81  58
# 8  71  19
# 9  81  33

# %%
tips1 = tips

# %%
tips
# Out:
#      total   tip  gender smoker   day    time  size
# 0    16.99  1.01  Female     No   Sun  Dinner     2
# 1    10.34  1.66    Male     No   Sun  Dinner     3
# 2    21.01  3.50    Male     No   Sun  Dinner     3
# 3    23.68  3.31    Male     No   Sun  Dinner     2
# 4    24.59  3.61  Female     No   Sun  Dinner     4
# ..     ...   ...     ...    ...   ...     ...   ...
# 239  29.03  5.92    Male     No   Sat  Dinner     3
# 240  27.18  2.00  Female    Yes   Sat  Dinner     2
# 241  22.67  2.00    Male    Yes   Sat  Dinner     2
# 242  17.82  1.75    Male     No   Sat  Dinner     2
# 243  18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips1.drop(['size'],axis = 1, inplace = True)

# %%
tips1
# Out:
#      total   tip  gender smoker   day    time
# 0    16.99  1.01  Female     No   Sun  Dinner
# 1    10.34  1.66    Male     No   Sun  Dinner
# 2    21.01  3.50    Male     No   Sun  Dinner
# 3    23.68  3.31    Male     No   Sun  Dinner
# 4    24.59  3.61  Female     No   Sun  Dinner
# ..     ...   ...     ...    ...   ...     ...
# 239  29.03  5.92    Male     No   Sat  Dinner
# 240  27.18  2.00  Female    Yes   Sat  Dinner
# 241  22.67  2.00    Male    Yes   Sat  Dinner
# 242  17.82  1.75    Male     No   Sat  Dinner
# 243  18.78  3.00  Female     No  Thur  Dinner
#
# [244 rows x 6 columns]

# %%
tips
# Out:
#      total   tip  gender smoker   day    time
# 0    16.99  1.01  Female     No   Sun  Dinner
# 1    10.34  1.66    Male     No   Sun  Dinner
# 2    21.01  3.50    Male     No   Sun  Dinner
# 3    23.68  3.31    Male     No   Sun  Dinner
# 4    24.59  3.61  Female     No   Sun  Dinner
# ..     ...   ...     ...    ...   ...     ...
# 239  29.03  5.92    Male     No   Sat  Dinner
# 240  27.18  2.00  Female    Yes   Sat  Dinner
# 241  22.67  2.00    Male    Yes   Sat  Dinner
# 242  17.82  1.75    Male     No   Sat  Dinner
# 243  18.78  3.00  Female     No  Thur  Dinner
#
# [244 rows x 6 columns]

# %%
id(tips),id(tips1)
# Out:
# (137786215622928, 137786215622928)

# %%
tips
# Out:
#      total   tip  gender smoker   day    time
# 0    16.99  1.01  Female     No   Sun  Dinner
# 1    10.34  1.66    Male     No   Sun  Dinner
# 2    21.01  3.50    Male     No   Sun  Dinner
# 3    23.68  3.31    Male     No   Sun  Dinner
# 4    24.59  3.61  Female     No   Sun  Dinner
# ..     ...   ...     ...    ...   ...     ...
# 239  29.03  5.92    Male     No   Sat  Dinner
# 240  27.18  2.00  Female    Yes   Sat  Dinner
# 241  22.67  2.00    Male    Yes   Sat  Dinner
# 242  17.82  1.75    Male     No   Sat  Dinner
# 243  18.78  3.00  Female     No  Thur  Dinner
#
# [244 rows x 6 columns]

# %%
tips2 = tips.copy()  # deep copy

# %%
id(tips2),id(tips)
# Out:
# (137786215621648, 137786215622928)

# %%
tips
# Out:
#      total   tip  gender smoker   day    time
# 0    16.99  1.01  Female     No   Sun  Dinner
# 1    10.34  1.66    Male     No   Sun  Dinner
# 2    21.01  3.50    Male     No   Sun  Dinner
# 3    23.68  3.31    Male     No   Sun  Dinner
# 4    24.59  3.61  Female     No   Sun  Dinner
# ..     ...   ...     ...    ...   ...     ...
# 239  29.03  5.92    Male     No   Sat  Dinner
# 240  27.18  2.00  Female    Yes   Sat  Dinner
# 241  22.67  2.00    Male    Yes   Sat  Dinner
# 242  17.82  1.75    Male     No   Sat  Dinner
# 243  18.78  3.00  Female     No  Thur  Dinner
#
# [244 rows x 6 columns]

# %%
tips.total
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total, Length: 244, dtype: float64

# %%
d
# Out:
# {'name': ['sumit', 'aniket', 'krish'], 'age': [1, 2, 3]}

# %%
# try to change the data type of columns

# %%
tips
# Out:
#      total   tip  gender smoker   day    time
# 0    16.99  1.01  Female     No   Sun  Dinner
# 1    10.34  1.66    Male     No   Sun  Dinner
# 2    21.01  3.50    Male     No   Sun  Dinner
# 3    23.68  3.31    Male     No   Sun  Dinner
# 4    24.59  3.61  Female     No   Sun  Dinner
# ..     ...   ...     ...    ...   ...     ...
# 239  29.03  5.92    Male     No   Sat  Dinner
# 240  27.18  2.00  Female    Yes   Sat  Dinner
# 241  22.67  2.00    Male    Yes   Sat  Dinner
# 242  17.82  1.75    Male     No   Sat  Dinner
# 243  18.78  3.00  Female     No  Thur  Dinner
#
# [244 rows x 6 columns]

# %%
tips.groupby(by = 'gender').get_group('Female')
# Out:
# /tmp/ipython-input-796569793.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby(by = 'gender').get_group('Female')
#      total   tip  gender smoker   day    time
# 0    16.99  1.01  Female     No   Sun  Dinner
# 4    24.59  3.61  Female     No   Sun  Dinner
# 11   35.26  5.00  Female     No   Sun  Dinner
# 14   14.83  3.02  Female     No   Sun  Dinner
# 16   10.33  1.67  Female     No   Sun  Dinner
# ..     ...   ...     ...    ...   ...     ...
# 226  10.09  2.00  Female    Yes   Fri   Lunch
# 229  22.12  2.88  Female    Yes   Sat  Dinner
# 238  35.83  4.67  Female     No   Sat  Dinner
# 240  27.18  2.00  Female    Yes   Sat  Dinner
# 243  18.78  3.00  Female     No  Thur  Dinner
#
# [87 rows x 6 columns]

# %%
grp_by_sex = tips.groupby(by = 'gender')
# Out:
# /tmp/ipython-input-2222777932.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grp_by_sex = tips.groupby(by = 'gender')

# %%
grp_by_sex['total'].sum()
# Out:
# gender
# Male      3256.82
# Female    1570.95
# Name: total, dtype: float64

# %%
grp_by_sex['tip'].mean()
# Out:
# gender
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
# on which day was most of the bill paid show me in descending order
# day is in the day column

# %%
total_by_day = tips.groupby(by = 'day')['total'].sum()
# Out:
# /tmp/ipython-input-1821410663.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   total_by_day = tips.groupby(by = 'day')['total'].sum()

# %%
total_by_day.sort_values(ascending = False)
# Out:
# day
# Sat     1778.40
# Sun     1627.16
# Thur    1096.33
# Fri      325.88
# Name: total, dtype: float64

# %%
# no of smokers and non smokers
tips['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
# how much bill was paid by non smoking females on saturday and sunday

# %%
tips['gender'].lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1220036248.py in <cell line: 0>()
# ----> 1 tips['gender'].lower()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
'SUmiT'.lower()
# Out:
# 'sumit'

# %%
tips['gender'] = tips['gender'].str.lower()

# %%
tips
# Out:
#      total   tip  gender smoker   day    time
# 0    16.99  1.01  female     No   Sun  Dinner
# 1    10.34  1.66    male     No   Sun  Dinner
# 2    21.01  3.50    male     No   Sun  Dinner
# 3    23.68  3.31    male     No   Sun  Dinner
# 4    24.59  3.61  female     No   Sun  Dinner
# ..     ...   ...     ...    ...   ...     ...
# 239  29.03  5.92    male     No   Sat  Dinner
# 240  27.18  2.00  female    Yes   Sat  Dinner
# 241  22.67  2.00    male    Yes   Sat  Dinner
# 242  17.82  1.75    male     No   Sat  Dinner
# 243  18.78  3.00  female     No  Thur  Dinner
#
# [244 rows x 6 columns]

# %%
# merge , join

# %%
# apply

# %%
def discount(n):
  if n > 20 :
    return n * (10/100)
  else:
    return 0

# %%
tips['discount'] =tips['total'].apply(discount)

# %%
tips['total'].apply(discount)
# Out:
# 0      0.000
# 1      0.000
# 2      2.101
# 3      2.368
# 4      2.459
#        ...
# 239    2.903
# 240    2.718
# 241    2.267
# 242    0.000
# 243    0.000
# Name: total, Length: 244, dtype: float64

# %%
tips
# Out:
#      total   tip  gender smoker   day    time  discount
# 0    16.99  1.01  female     No   Sun  Dinner     0.000
# 1    10.34  1.66    male     No   Sun  Dinner     0.000
# 2    21.01  3.50    male     No   Sun  Dinner     2.101
# 3    23.68  3.31    male     No   Sun  Dinner     2.368
# 4    24.59  3.61  female     No   Sun  Dinner     2.459
# ..     ...   ...     ...    ...   ...     ...       ...
# 239  29.03  5.92    male     No   Sat  Dinner     2.903
# 240  27.18  2.00  female    Yes   Sat  Dinner     2.718
# 241  22.67  2.00    male    Yes   Sat  Dinner     2.267
# 242  17.82  1.75    male     No   Sat  Dinner     0.000
# 243  18.78  3.00  female     No  Thur  Dinner     0.000
#
# [244 rows x 7 columns]

# %%
# explore apply a little more on the official documentation of pandas
# check out how to mount the file to your gdrive

# %%
tips.to_csv('/content/new_data.csv')

# %%
pwd
# Out:
# '/content'

# %%
import plotly.express as px

# %%
dir(px)
# Out:
# ['Constant',
#  'IdentityMap',
#  'NO_COLOR',
#  'Range',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_chart_types',
#  '_core',
#  '_doc',
#  '_imshow',
#  '_special_inputs',
#  'area',
#  'bar',
#  'bar_polar',
#  'box',
#  'choropleth',
#  'choropleth_map',
#  'choropleth_mapbox',
#  'colors',
#  'data',
#  'defaults',
#  'density_contour',
#  'density_heatmap',
#  'density_map',
#  'density_mapbox',
#  'ecdf',
#  'funnel',
#  'funnel_area',
#  'get_trendline_results',
#  'histogram',
#  'icicle',
#  'imshow',
#  'imshow_utils',
#  'line',
#  'line_3d',
#  'line_geo',
#  'line_map',
#  'line_mapbox',
#  'line_polar',
#  'line_ternary',
#  'optional_imports',
#  'parallel_categories',
#  'parallel_coordinates',
#  'pd',
#  'pie',
#  'scatter',
#  'scatter_3d',
#  'scatter_geo',
#  'scatter_map',
#  'scatter_mapbox',
#  'scatter_matrix',
#  'scatter_polar',
# ...

# %%
# univariate and bivariate
# check out charts under uni and bi variate analysis

# %%
import plotly.express as px

# %%
tips
# Out:
#      total   tip  gender smoker   day    time  discount
# 0    16.99  1.01  female     No   Sun  Dinner     0.000
# 1    10.34  1.66    male     No   Sun  Dinner     0.000
# 2    21.01  3.50    male     No   Sun  Dinner     2.101
# 3    23.68  3.31    male     No   Sun  Dinner     2.368
# 4    24.59  3.61  female     No   Sun  Dinner     2.459
# ..     ...   ...     ...    ...   ...     ...       ...
# 239  29.03  5.92    male     No   Sat  Dinner     2.903
# 240  27.18  2.00  female    Yes   Sat  Dinner     2.718
# 241  22.67  2.00    male    Yes   Sat  Dinner     2.267
# 242  17.82  1.75    male     No   Sat  Dinner     0.000
# 243  18.78  3.00  female     No  Thur  Dinner     0.000
#
# [244 rows x 7 columns]

# %%
px.scatter(tips,x = 'total',y = 'tip')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
